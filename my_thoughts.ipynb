# %%
api_client = metaPyScape.ApiClient(configuration=configuration, 
                                   header_name="api-key", 
                                   header_value=config.get("api-key", None))

project_api = metaPyScape.ProjectsApi(api_client)
feature_table_api = metaPyScape.FeaturetableApi(api_client)

# %% [markdown]
# api_client is an object/instance of the ApiClient class (for what?)
#
#
#
# project_api stores the information
#
# print(type(api_client))             class 'metaPyScape.api_client.ApiClient'>
# print(type(project_api))            class 'metaPyScape.api.projects_api.ProjectsApi'
# print(type(api_response))           class 'list'
# print(type(projectId))              class 'str'
# print(type(projectInfo))            class 'metaPyScape.models.project_info.ProjectInfo'
# print(type(experiment))             class 'metaPyScape.models.experiment.Experiment'

# %%
# api response = list_all_projects method --> returns a list of all projects (2 in this case)

[{'experiments': [{'feature_tables': [{'id': '2c32680e-debc-4f77-8970-78cf547d9875',
                                      'name': 'QJZ-2025-02-20-source-comparison-pos',
                                      'polarity': 'POSITIVE',
                                      'processing_workflow': 'ferra4d_4.9.20'},
                                     {'id': 'd9a170b3-307e-463d-82fa-fc58113f17d0',
                                      'name': 'QJZ-2025-02-20-source-comparison-pos',
                                      'polarity': 'POSITIVE',
                                      'processing_workflow': 'ferra4d_4.9.20'},
                                     {'id': 'b4b52da3-23b6-4301-ac9c-168b98c86314',
                                      'name': 'QJZ-2025-02-20-source-comparison-neg',
                                      'polarity': 'NEGATIVE',
                                      'processing_workflow': 'ferra4d_4.9.20'}],
                  'id': '6f281a94-40d5-425b-be62-e283a964796e',
                  'name': 'QJZ-2025-02-20-source-comparison'}],
 'id': '87d912bb-4153-4443-bf2a-1036548a0961',
 'name': 'QJZ-2025-02-20-source-comparison'},
 {'experiments': [{'feature_tables': [{'id': '934dfd4b-efcb-4430-9dba-cd9d728edc99',
                                      'name': 'Bucket Table 1',
                                      'polarity': None,
                                      'processing_workflow': 'ProfileAnalysis '
                                                             '2.3.1'}],
                  'id': 'b6f50ddd-bfd2-40cb-9b48-793b33910e9d',
                  'name': 'Coffee Tutorial Experiment'}],
 'id': '505a857d-8fac-46ad-938c-32824bb69ad4',
 'name': 'Coffee Tutorial Project'}]


 #projectInfo = 

 {'attribute': [],
 'creation_date': 1740738555157,
 'description': 'QJZ-2025-02-20-source-comparison',
 'experiments': [{'creation_date': 1740738554486,
                  'experiment_id': '6f281a94-40d5-425b-be62-e283a964796e',
                  'group_colors': None,
                  'group_symbols': None,
                  'name': 'QJZ-2025-02-20-source-comparison',
                  'samples': [{'attributes': [],
                               'creation_date': 1740738554486,
                               'name': 'SAR-270-II-pagt-1009-#1-pos-OS_P1-A-5_1',
                               'sample_id': '87d912bb-4153-4443-bf2a-1036548a0961',
                               'sample_type': 'SAMPLE'}]}],
 'name': 'QJZ-2025-02-20-source-comparison',
 'owner': 'Metabo User',
 'project_id': '87d912bb-4153-4443-bf2a-1036548a0961'}

# %% [markdown]
#    These are all Metadata entries in the predefined table
#
#    --> what is important, what do io look for during the mapping?
#
#     prefix='MTD',
#     mz_tab_version="2.0.0-M",
#     mz_tab_id=experiment.id,                    welche id hier? die der featuretable?
#     title=projectInfo.name,
#     description=projectInfo.description,
#     sample_processing="standard protocols",
#     instrument=None,
#     software="MetaboScape",
#     publication=None,
#     contact=projectInfo.owner,
#     uri=None,
#     external_study_uri=None,
#     quantification_method="label-free",
#     study_variable="notNone",                   darüber hatten wir gesprochen, nochmal überlegen, könnte sein dass diese info fehlt im cource-comparison beispiel
#     ms_run="notNone",                           hier die liste einfügen an samples die wir haben? also die 18 stück. nehme ich hier dann die sampleIds?
#     assay="notNone",
#     sample=None,
#     custom=None,
#     cv="notNone",
#     database="inhouse ?",
#     derivatization_agent=None,
#     small_molecule_quantification_unit="notNone",
#     small_molecule_feature_quantification_unit="notNone",
#     small_molecule_identification_reliability=None,
#     id_confidence_measure="notNone" ,
#     colunit_small_molecule=None,
#     colunit_small_molecule_feature=None,
#     colunit_small_molecule_evidence=None

# %%
# part of the downloaded featuretable

63-ac22-b269bbe71dc5',
 'mass': 674.6675246085335,
 'primary_annotation': None,
 'rt_in_seconds': 1031.201416015625,
 'user_flags': []},
 {'all_annotations': [],
 'feature_ions': [{'ccs': 178.9428253173828,
                   'id': '07db8f2a-d073-48fc-8d2d-6131a3f47b70',
                   'ion_notation': '[M+H]+',
                   'main_ion': True,
                   'mz': 337.1039749242839}],
 'id': '390c2806-9a0e-4cec-b462-610be587b12d',
 'mass': 336.0966984720539,
 'primary_annotation': None,
 'rt_in_seconds': 1030.4671630859375,
 'user_flags': []},
 {'all_annotations': [],
 'feature_ions': [{'ccs': 179.09228515625,
                   'id': '4c116229-6daa-4799-bc59-0c4c52d72493',
                   'ion_notation': '[M+H]+',
                   'main_ion': True,
                   'mz': 337.1016182520972}],
 'id': '37fdc3e7-faa2-4fde-9590-1c23b41db9a2',
 'mass': 336.0943417998672,
 'primary_annotation': None,
 'rt_in_seconds': 1035.909423828125,
 'user_flags': []},
 {'all_annotations': [],
                   'id': '4c116229-6daa-4799-bc59-0c4c52d72493',
                   'ion_notation': '[M+H]+',
                   'main_ion': True,
                   'mz': 337.1016182520972}],
 'id': '37fdc3e7-faa2-4fde-9590-1c23b41db9a2',
 'mass': 336.0943417998672,
 'primary_annotation': None,
 'rt_in_seconds': 1035.909423828125,
 'user_flags': []},
 {'all_annotations': [],
                   'ion_notation': '[M+H]+',
                   'main_ion': True,
                   'mz': 337.1016182520972}],
 'id': '37fdc3e7-faa2-4fde-9590-1c23b41db9a2',
 'mass': 336.0943417998672,
 'primary_annotation': None,
 'rt_in_seconds': 1035.909423828125,
 'user_flags': []},
 {'all_annotations': [],
                   'mz': 337.1016182520972}],
 'id': '37fdc3e7-faa2-4fde-9590-1c23b41db9a2',
 'mass': 336.0943417998672,
 'primary_annotation': None,
 'rt_in_seconds': 1035.909423828125,
 'user_flags': []},
 {'all_annotations': [],
 'mass': 336.0943417998672,
 'primary_annotation': None,
 'rt_in_seconds': 1035.909423828125,
 'user_flags': []},
 {'all_annotations': [],
 'rt_in_seconds': 1035.909423828125,
 'user_flags': []},
 {'all_annotations': [],
 'user_flags': []},
 {'all_annotations': [],
 {'all_annotations': [],
 'feature_ions': [{'ccs': 245.91949462890625,
 'feature_ions': [{'ccs': 245.91949462890625,
                   'id': '1acf1c84-8fd2-49b6-b143-ed89bbda8e4f',
                   'ion_notation': '[M+H]+',
                   'ion_notation': '[M+H]+',
                   'main_ion': True,
                   'main_ion': True,
                   'mz': 337.10408845919653}],
                   'mz': 337.10408845919653}],
 'id': '506d0096-07a4-411b-994b-51856ab7aa62',
 'mass': 336.09681200696656,
 'id': '506d0096-07a4-411b-994b-51856ab7aa62',
 'mass': 336.09681200696656,
 'primary_annotation': None,
 'rt_in_seconds': 1046.289794921875,
 'mass': 336.09681200696656,
 'primary_annotation': None,
 'rt_in_seconds': 1046.289794921875,
 'user_flags': []},
 'primary_annotation': None,
 'rt_in_seconds': 1046.289794921875,
 'user_flags': []},
 {'all_annotations': [],
 'rt_in_seconds': 1046.289794921875,
 'user_flags': []},
 {'all_annotations': [],
 'user_flags': []},
 {'all_annotations': [],
 {'all_annotations': [],
 'feature_ions': [{'ccs': 178.9292755126953,
                   'id': '066afdbd-17ba-4157-992c-45d613ee1389',
 'feature_ions': [{'ccs': 178.9292755126953,
                   'id': '066afdbd-17ba-4157-992c-45d613ee1389',
                   'id': '066afdbd-17ba-4157-992c-45d613ee1389',
                   'ion_notation': '[M+H]+',
                   'main_ion': True,
                   'main_ion': True,
                   'mz': 337.10410629099414}],
 'id': 'e9076883-08bb-4939-9afc-144e18cc1457',                          #this is the last ID
 'mass': 336.09682983876417,
 'primary_annotation': None,
 'rt_in_seconds': 1061.6553955078125,
 'user_flags': []}]

# %% [markdown]
# api_response_ft has 937 entries, every entry is an object of class 'metaPyScape.models.feature.Feature' --> how can i access different information in here?

# %%
# first entry of the api:_response_ft list: one entry of a list has the type: <class 'metaPyScape.models.feature.Feature'>

{'all_annotations': [],
 'feature_ions': [{'ccs': 161.7107391357422,
                   'id': '218a6698-ed53-4772-8ff8-f372cb92d93d',
                   'ion_notation': '[M+H]+',
                   'main_ion': True,
                   'mz': 104.10685559415053}],
 'id': 'bab51b50-bd0e-4b21-9ce1-3661cfbca7de',
 'mass': 103.09957914192053,
 'primary_annotation': None,
 'rt_in_seconds': 31.070858001708984,
 'user_flags': []}

#second feature: class 'metaPyScape.models.feature.Feature' 

{'all_annotations': [],
 'feature_ions': [{'ccs': 152.70164489746094,
                   'id': '44a46720-1dcc-4c25-aa08-bca3f76d58de',
                   'ion_notation': '[M+H]+',
                   'main_ion': True,
                   'mz': 258.11018987232205}],
 'id': 'e96f4792-ba67-43db-b4a2-7f1b7505da26',
 'mass': 257.1029134200921,
 'primary_annotation': None,
 'rt_in_seconds': 31.103002548217773,
 'user_flags': []}

# %% [markdown]
# api_response_samples is a list, every single entry is an object of class metaPyScape.models.sample.Sample

# %%
# api_response_samples

[{'analysis': [{'id': '1abc4fcc-cb80-406c-b2ad-8026af2f6589',
               'include': True,
               'name': 'Methanol-pos-2-OS_P1-F-9_1_12649'},
              {'id': '3aa7f2d9-eefa-4aaa-834d-6683992ce5ad',
               'include': True,
               'name': 'Coumarin-pos-1-OS_P1-F-8_1_12650'},
              {'id': '6620a703-fca6-455d-877d-723eccb24ee5',
               'include': True,
               'name': 'Methanol-pos-3-OS_P1-F-9_1_12651'},
              {'id': '11011f26-aaaa-472f-9705-99f063649420',
               'include': True,
               'name': 'MM10-1-1000-pos-OS_P1-A-1_1_12652'},
              {'id': '60a52803-5714-456e-80c8-21fdab049b0e',
               'include': True,
               'name': 'MM10-1-100-pos-OS_P1-A-2_1_12653'},
              {'id': '7695f111-506d-4b07-9290-9e5cc9754a05',
               'include': True,
               'name': '5-CK-R-pos-OS_P1-A-3_1_12654'},
              {'id': 'e4f381e7-5117-4fbd-85f2-451fd9525645',
               'include': True,
               'name': '10-R-pos-OS_P1-A-4_1_12655'},
              {'id': '35659ea5-a09a-48f7-9ef5-4782c5d93b85',
               'include': True,
               'name': 'SAR-270-II-pagt-1009-#1-pos-OS_P1-A-5_1_12656'},
              {'id': 'a928fc72-44f8-47f7-be5c-4a0a937f28ab',
               'include': True,
               'name': 'RRA-3rd-repli-Col-0-nt1-pos-OS_P1-A-6_1_12657'},
              {'id': '90c6abf5-1eb7-4a0b-970b-bdf449c59be7',
               'include': True,
               'name': 'Methanol-pos-2-NS_P1-F-9_1_12675'},
              {'id': '50859d14-d1d3-48d7-a6a3-76a403aeb913',
               'include': True,
               'name': 'Coumarin-pos-1-NS_P1-F-8_1_12676'},
              {'id': '11f93ffe-3d6f-4217-a25b-02ed8e277581',
               'include': True,
               'name': 'Methanol-pos-3-NS_P1-F-9_1_12677'},
              {'id': 'e8f856e2-f28e-4582-8c5f-7403e2db3c26',
               'include': True,
               'name': 'MM10-1-1000-pos-NS_P1-A-1_1_12678'},
              {'id': '803fa77b-3fd7-41b0-a7c3-6ffe7fd369b5',
               'include': True,
               'name': 'MM10-1-100-pos-NS_P1-A-2_1_12679'},
              {'id': '7b6ef5e0-7340-4392-9740-3a5a9d6fe014',
               'include': True,
               'name': '5-CK-R-pos-NS_P1-A-3_1_12680'},
              {'id': '0e5afea6-e8bf-4b70-9937-e13e92e1957e',
               'include': True,
               'name': '10-R-pos-NS_P1-A-4_1_12681'},
              {'id': '7b24362f-39ac-41b6-9696-058aad97fa72',
               'include': True,
               'name': 'SAR-270-II-pagt-1009-#1-pos-NS_P1-A-5_1_12682'},
              {'id': 'c98b1e27-1bcf-44aa-ae10-8f5aac1e8bdf',
               'include': True,
               'name': 'RRA-3rd-repli-Col-0-nt1-pos-NS_P1-A-6_1_12683'}],
 'attributes': [],
 'id': 'fb4f7111-4707-4a8e-8a53-8529f1d063ce',
 'name': 'SAR-270-II-pagt-1009-#1-pos-OS_P1-A-5_1',
 'type': 'SAMPLE',
 'volume': {'unit': None, 'volume': 1.0}}]

# %%
# output after commands:
# first_sample = api_response_sample[0] 
# sample_info = first_sample.analysis 

[{'id': '1abc4fcc-cb80-406c-b2ad-8026af2f6589',
 'include': True,
 'name': 'Methanol-pos-2-OS_P1-F-9_1_12649'}, {'id': '3aa7f2d9-eefa-4aaa-834d-6683992ce5ad',
 'include': True,
 'name': 'Coumarin-pos-1-OS_P1-F-8_1_12650'}, {'id': '6620a703-fca6-455d-877d-723eccb24ee5',
 'include': True,
 'name': 'Methanol-pos-3-OS_P1-F-9_1_12651'}, {'id': '11011f26-aaaa-472f-9705-99f063649420',
 'include': True,
 'name': 'MM10-1-1000-pos-OS_P1-A-1_1_12652'}, {'id': '60a52803-5714-456e-80c8-21fdab049b0e',
 'include': True,
 'name': 'MM10-1-100-pos-OS_P1-A-2_1_12653'}, {'id': '7695f111-506d-4b07-9290-9e5cc9754a05',
 'include': True,
 'name': '5-CK-R-pos-OS_P1-A-3_1_12654'}, {'id': 'e4f381e7-5117-4fbd-85f2-451fd9525645',
 'include': True,
 'name': '10-R-pos-OS_P1-A-4_1_12655'}, {'id': '35659ea5-a09a-48f7-9ef5-4782c5d93b85',
 'include': True,
 'name': 'SAR-270-II-pagt-1009-#1-pos-OS_P1-A-5_1_12656'}, {'id': 'a928fc72-44f8-47f7-be5c-4a0a937f28ab',
 'include': True,
 'name': 'RRA-3rd-repli-Col-0-nt1-pos-OS_P1-A-6_1_12657'}, {'id': '90c6abf5-1eb7-4a0b-970b-bdf449c59be7',
 'include': True,
 'name': 'Methanol-pos-2-NS_P1-F-9_1_12675'}, {'id': '50859d14-d1d3-48d7-a6a3-76a403aeb913',
 'include': True,
 'name': 'Coumarin-pos-1-NS_P1-F-8_1_12676'}, {'id': '11f93ffe-3d6f-4217-a25b-02ed8e277581',
 'include': True,
 'name': 'Methanol-pos-3-NS_P1-F-9_1_12677'}, {'id': 'e8f856e2-f28e-4582-8c5f-7403e2db3c26',
 'include': True,
 'name': 'MM10-1-1000-pos-NS_P1-A-1_1_12678'}, {'id': '803fa77b-3fd7-41b0-a7c3-6ffe7fd369b5',
 'include': True,
 'name': 'MM10-1-100-pos-NS_P1-A-2_1_12679'}, {'id': '7b6ef5e0-7340-4392-9740-3a5a9d6fe014',
 'include': True,
 'name': '5-CK-R-pos-NS_P1-A-3_1_12680'}, {'id': '0e5afea6-e8bf-4b70-9937-e13e92e1957e',
 'include': True,
 'name': '10-R-pos-NS_P1-A-4_1_12681'}, {'id': '7b24362f-39ac-41b6-9696-058aad97fa72',
 'include': True,
 'name': 'SAR-270-II-pagt-1009-#1-pos-NS_P1-A-5_1_12682'}, {'id': 'c98b1e27-1bcf-44aa-ae10-8f5aac1e8bdf',
 'include': True,
 'name': 'RRA-3rd-repli-Col-0-nt1-pos-NS_P1-A-6_1_12683'}]

#one entry of this list has the type metaPyScape.models.analysis.Analysis
